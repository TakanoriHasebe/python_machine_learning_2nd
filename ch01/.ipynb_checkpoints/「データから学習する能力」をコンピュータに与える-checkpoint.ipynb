# %% [markdown]
# ## 回帰

# %% [markdown]
# 複数の予測変数（説明変数）と連続値の応答変数が与えられ<br>
# 説明変数を$x$、応答変数を$y$として、サンプル点との距離（主に平均２乗誤差）が最も短くなる直線を当てはめる。<br>

# %%
from IPython.display import Image
Image(filename='00.png', width=300)

# %% [markdown]
# ## 「教師なし学習」による隠れた構造の発見

# %% [markdown]
# ### クラスタリングによるグループの発見

# %% [markdown]
# 特徴量の$x_{1}$と$x_{2}$の類似性に基づき、データを３のグループに分割している。

# %%
from IPython.display import Image
Image(filename='01.png', width=300)
